# %% [markdown]
# # Individual Person Carbon Footprint Data Cleaner

# %% [markdown]
# This notebook is used to load data from the spreadsheet containing the data about the carboon footprints of each individual person from the given .xlsx data file given as part of the Wells Fargo Campus Analytics Challenge.

# %% [markdown]
# ## Section 1: Importing the required libraries

# %% [markdown]
# Import the required libraries for loading and augmenting the dataset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Section 2: Loading the Data

# %% [markdown]
# First we will load the data from the first spreadsheet ('Individuals') from given .xlsx file into a dataframe

# %%
# Loading the dataset into a dataframe
individuals_carbon_footprint_df = pd.read_excel(r'Data.xlsx', sheet_name='Individuals')

# %%
individuals_carbon_footprint_df
# Out:
#        Indnum  Group                                        Activity  Units  \
# 0           1      1                        Household heating => 70F  hours
# 1           1      1                         Household heating < 70F  hours
# 2           1      1                                Use of heat pump  hours
# 3           1      1                          Use of air conditioner  hours
# 4           1      2                                  shower - short  count
# 5           1      2                         shower - long (> 3 min)  count
# 6           1      2                                            bath  count
# 7           1      2                                         wash-up  count
# 8           1      3                               use of dishwasher  count
# 9           1      3                           use of clothes washer  count
# 10          1      3                            use of clothes dryer  count
# 11          1      3                            use of cooking range  count
# 12          1      3                                    use of  oven  count
# 13          1      3      use of self-clean feature of electric oven  count
# 14          1      3             Small kitchen appliance in the home  count
# 15          1      4                                 TV/computer use  count
# 16          1      5                        air travel - large plane  miles
# 17          1      5           air travel - small  plane (<50 seats)  miles
# 18          1      5                            car trips- self only  miles
# 19          1      5                     car trips - driver and self  miles
# 20          1      5  car trips - 2+ people with multiple end points  miles
# 21          1      5        trips using public ground transportation   bags
# 22          1      6                        bags of garbage disposed   bags
# 23          1      6       bags of recycling deposited (negative CF)   bags
# 24          1      6         bags of compost deposited (negative CF)   bags
# 25          1      6            hazardous or electric items disposed   bags
# 26          1      6                            large items disposed  items
# 27          2      1                        Household heating => 70F  count
# 28          2      1                         Household heating < 70F  count
# 29          2      1                                Use of heat pump  count
# ...       ...    ...                                             ...    ...
# 27024    1001      6         bags of compost deposited (negative CF)   bags
# 27025    1001      6            hazardous or electric items disposed   bags
# 27026    1001      6                            large items disposed  items
# 27027    1002      1                        Household heating => 70F  count
# 27028    1002      1                         Household heating < 70F  count
# 27029    1002      1                                Use of heat pump  count
# 27030    1002      1                          Use of air conditioner  count
# 27031    1002      2                                  shower - short  count
# 27032    1002      2                         shower - long (> 3 min)  count
# 27033    1002      2                                            bath  count
# 27034    1002      2                                         wash-up  count
# 27035    1002      3                               use of dishwasher  count
# 27036    1002      3                           use of clothes washer  count
# 27037    1002      3                            use of clothes dryer  count
# 27038    1002      3                            use of cooking range  count
# 27039    1002      3                                    use of  oven  count
# 27040    1002      3      use of self-clean feature of electric oven  count
# 27041    1002      3             Small kitchen appliance in the home  count
# 27042    1002      4                                 TV/computer use  count
# 27043    1002      5                        air travel - large plane  miles
# 27044    1002      5           air travel - small  plane (<50 seats)  miles
# 27045    1002      5                            car trips- self only  miles
# 27046    1002      5                     car trips - driver and self  miles
# 27047    1002      5  car trips - 2+ people with multiple end points  miles
# 27048    1002      5        trips using public ground transportation   bags
# 27049    1002      6                        bags of garbage disposed   bags
# 27050    1002      6       bags of recycling deposited (negative CF)   bags
# 27051    1002      6         bags of compost deposited (negative CF)   bags
# 27052    1002      6            hazardous or electric items disposed   bags
# 27053    1002      6                            large items disposed  items
#
#        Consumption  Quality_of_Life_Importance__1_10  \
# 0              2.0                              88.0
# 1             10.0                              85.0
# 2              NaN                              50.0
# 3             20.0                              45.0
# 4              5.0                              98.0
# 5             30.0                              74.0
# 6              NaN                              14.0
# 7             44.0                              27.0
# 8              NaN                              20.0
# 9              2.0                              28.0
# 10             3.0                              11.0
# 11             NaN                               NaN
# 12             9.0                              35.0
# 13             3.0                              15.0
# 14             NaN                               NaN
# 15            64.0                              23.0
# 16          2747.0                              42.0
# 17             NaN                               NaN
# 18           443.0                              44.0
# 19            38.0                              27.0
# 20            10.0                               NaN
# 21            15.0                              49.0
# 22            26.0                              41.0
# 23             NaN                               NaN
# 24             3.0                               6.0
# 25             NaN                               NaN
# 26             2.0                              15.0
# 27             7.0                              77.0
# 28             2.0                              61.0
# 29             NaN                              55.0
# ...            ...                               ...
# 27024          NaN                               NaN
# 27025          NaN                               NaN
# 27026          NaN                              19.0
# 27027          1.0                              82.0
# 27028          2.0                              83.0
# 27029          NaN                              50.0
# 27030         16.0                              56.0
# 27031          8.0                              84.0
# 27032         23.0                              89.0
# 27033          NaN                              11.0
# 27034         42.0                              34.0
# 27035          NaN                              20.0
# 27036          3.0                              32.0
# 27037          1.0                              14.0
# 27038          NaN                               NaN
# 27039         12.0                              33.0
# 27040          3.0                              20.0
# 27041          NaN                               NaN
# 27042         64.0                              29.0
# 27043       3166.0                              42.0
# 27044          NaN                               NaN
# 27045        323.0                              54.0
# 27046         11.0                              22.0
# 27047          NaN                               NaN
# 27048         16.0                              57.0
# 27049         26.0                              51.0
# 27050          NaN                               NaN
# 27051          7.0                              15.0
# 27052          NaN                               NaN
# 27053          1.0                              14.0
#
#        solar_powered__water_heater  gas_water_heater  \
# 0                              NaN               NaN
# 1                              1.0               1.0
# 2                              NaN               NaN
# 3                              NaN               NaN
# 4                              NaN               NaN
# 5                              NaN               NaN
# 6                              NaN               NaN
# 7                              NaN               1.0
# 8                              NaN               NaN
# 9                              NaN               NaN
# 10                             NaN               NaN
# 11                             NaN               NaN
# 12                             NaN               NaN
# 13                             NaN               NaN
# 14                             NaN               NaN
# 15                             NaN               NaN
# 16                             NaN               NaN
# 17                             NaN               NaN
# 18                             NaN               NaN
# 19                             NaN               NaN
# 20                             NaN               NaN
# 21                             NaN               NaN
# 22                             NaN               NaN
# 23                             NaN               NaN
# 24                             NaN               NaN
# 25                             NaN               NaN
# 26                             NaN               NaN
# 27                             NaN               NaN
# 28                             NaN               NaN
# 29                             NaN               NaN
# ...                            ...               ...
# 27024                          NaN               NaN
# 27025                          NaN               NaN
# 27026                          NaN               NaN
# 27027                          NaN               NaN
# 27028                          NaN               NaN
# 27029                          NaN               NaN
# 27030                          NaN               NaN
# 27031                          1.0               NaN
# 27032                          NaN               NaN
# 27033                          NaN               NaN
# 27034                          NaN               NaN
# 27035                          NaN               NaN
# 27036                          NaN               NaN
# 27037                          1.0               NaN
# 27038                          NaN               NaN
# 27039                          NaN               NaN
# 27040                          NaN               NaN
# 27041                          NaN               NaN
# 27042                          NaN               NaN
# 27043                          NaN               NaN
# 27044                          NaN               NaN
# 27045                          NaN               NaN
# 27046                          NaN               NaN
# 27047                          NaN               NaN
# 27048                          NaN               NaN
# 27049                          NaN               NaN
# 27050                          NaN               NaN
# 27051                          NaN               NaN
# 27052                          NaN               NaN
# 27053                          NaN               NaN
#
#        electric_water_heater___peak_hou  electric_water_heater___off_peak  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# 5                                   NaN                               NaN
# 6                                   NaN                               NaN
# 7                                   NaN                               NaN
# 8                                   NaN                               NaN
# 9                                   NaN                               NaN
# 10                                  NaN                               NaN
# 11                                  NaN                               NaN
# 12                                  NaN                               NaN
# 13                                  NaN                               NaN
# 14                                  NaN                               NaN
# 15                                  NaN                               NaN
# 16                                  NaN                               NaN
# 17                                  NaN                               NaN
# 18                                  NaN                               NaN
# 19                                  NaN                               NaN
# 20                                  NaN                               NaN
# 21                                  NaN                               NaN
# 22                                  NaN                               NaN
# 23                                  NaN                               NaN
# 24                                  NaN                               NaN
# 25                                  NaN                               NaN
# 26                                  NaN                               NaN
# 27                                  NaN                               NaN
# 28                                  NaN                               NaN
# 29                                  NaN                               NaN
# ...                                 ...                               ...
# 27024                               NaN                               NaN
# 27025                               NaN                               NaN
# 27026                               NaN                               NaN
# 27027                               1.0                               NaN
# 27028                               NaN                               1.0
# 27029                               NaN                               NaN
# 27030                               NaN                               NaN
# 27031                               NaN                               NaN
# 27032                               NaN                               1.0
# 27033                               NaN                               NaN
# 27034                               NaN                               NaN
# 27035                               NaN                               NaN
# 27036                               NaN                               NaN
# 27037                               NaN                               NaN
# 27038                               NaN                               NaN
# 27039                               NaN                               NaN
# 27040                               NaN                               NaN
# 27041                               NaN                               NaN
# 27042                               NaN                               NaN
# 27043                               NaN                               NaN
# 27044                               NaN                               NaN
# 27045                               NaN                               NaN
# 27046                               NaN                               NaN
# 27047                               NaN                               NaN
# 27048                               NaN                               NaN
# 27049                               NaN                               NaN
# 27050                               NaN                               NaN
# 27051                               NaN                               NaN
# 27052                               NaN                               NaN
# 27053                               NaN                               NaN
#
#        gas  natural_gas  hybrid  electric___peak_hours  \
# 0      NaN          1.0     NaN                    NaN
# 1      NaN          1.0     NaN                    NaN
# 2      NaN          NaN     NaN                    NaN
# 3      NaN          NaN     NaN                    NaN
# 4      NaN          NaN     NaN                    NaN
# 5      NaN          NaN     NaN                    NaN
# 6      NaN          NaN     NaN                    NaN
# 7      NaN          NaN     NaN                    NaN
# 8      NaN          NaN     NaN                    NaN
# 9      NaN          NaN     NaN                    NaN
# 10     NaN          NaN     NaN                    NaN
# 11     NaN          NaN     NaN                    NaN
# 12     NaN          NaN     NaN                    NaN
# 13     NaN          NaN     NaN                    NaN
# 14     NaN          NaN     NaN                    NaN
# 15     NaN          NaN     NaN                    NaN
# 16     NaN          NaN     NaN                    NaN
# 17     NaN          NaN     NaN                    NaN
# 18     1.0          NaN     NaN                    NaN
# 19     1.0          NaN     NaN                    NaN
# 20     1.0          NaN     NaN                    NaN
# 21     NaN          NaN     NaN                    NaN
# 22     NaN          NaN     NaN                    NaN
# 23     NaN          NaN     NaN                    NaN
# 24     NaN          NaN     NaN                    NaN
# 25     NaN          NaN     NaN                    NaN
# 26     NaN          NaN     NaN                    NaN
# 27     NaN          1.0     NaN                    NaN
# 28     NaN          1.0     NaN                    NaN
# 29     NaN          NaN     NaN                    NaN
# ...    ...          ...     ...                    ...
# 27024  NaN          NaN     NaN                    NaN
# 27025  NaN          NaN     NaN                    NaN
# 27026  NaN          NaN     NaN                    NaN
# 27027  NaN          1.0     NaN                    NaN
# 27028  NaN          1.0     NaN                    NaN
# 27029  NaN          NaN     NaN                    NaN
# 27030  NaN          NaN     NaN                    NaN
# 27031  NaN          NaN     1.0                    NaN
# 27032  NaN          NaN     NaN                    NaN
# 27033  NaN          NaN     NaN                    NaN
# 27034  NaN          NaN     NaN                    NaN
# 27035  NaN          NaN     NaN                    NaN
# 27036  NaN          NaN     NaN                    NaN
# 27037  NaN          NaN     NaN                    NaN
# 27038  NaN          NaN     NaN                    NaN
# 27039  NaN          NaN     NaN                    NaN
# 27040  NaN          NaN     NaN                    NaN
# 27041  NaN          NaN     NaN                    NaN
# 27042  NaN          NaN     NaN                    NaN
# 27043  NaN          NaN     NaN                    NaN
# 27044  NaN          NaN     NaN                    NaN
# 27045  1.0          NaN     NaN                    NaN
# 27046  1.0          NaN     NaN                    NaN
# 27047  1.0          NaN     NaN                    NaN
# 27048  NaN          NaN     NaN                    NaN
# 27049  NaN          NaN     NaN                    NaN
# 27050  NaN          NaN     NaN                    NaN
# 27051  NaN          NaN     NaN                    NaN
# 27052  NaN          NaN     NaN                    NaN
# 27053  NaN          NaN     NaN                    NaN
#
#        electric___off_peak_hours  jetfuel
# 0                            NaN      NaN
# 1                            NaN      NaN
# 2                            NaN      NaN
# 3                            NaN      NaN
# 4                            NaN      NaN
# 5                            NaN      NaN
# 6                            NaN      NaN
# 7                            NaN      NaN
# 8                            NaN      NaN
# 9                            NaN      NaN
# 10                           NaN      NaN
# 11                           NaN      NaN
# 12                           NaN      NaN
# 13                           NaN      NaN
# 14                           NaN      NaN
# 15                           NaN      NaN
# 16                           NaN      NaN
# 17                           NaN      NaN
# 18                           NaN      NaN
# 19                           NaN      NaN
# 20                           NaN      NaN
# 21                           NaN      NaN
# 22                           NaN      NaN
# 23                           NaN      NaN
# 24                           NaN      NaN
# 25                           NaN      NaN
# 26                           NaN      NaN
# 27                           NaN      NaN
# 28                           NaN      NaN
# 29                           NaN      NaN
# ...                          ...      ...
# 27024                        NaN      NaN
# 27025                        NaN      NaN
# 27026                        NaN      NaN
# 27027                        NaN      NaN
# 27028                        NaN      NaN
# 27029                        NaN      NaN
# 27030                        NaN      NaN
# 27031                        NaN      NaN
# 27032                        NaN      NaN
# 27033                        NaN      NaN
# 27034                        NaN      NaN
# 27035                        NaN      NaN
# 27036                        NaN      NaN
# 27037                        1.0      NaN
# 27038                        1.0      NaN
# 27039                        1.0      NaN
# 27040                        NaN      NaN
# 27041                        NaN      NaN
# 27042                        NaN      NaN
# 27043                        NaN      NaN
# 27044                        NaN      NaN
# 27045                        NaN      NaN
# 27046                        NaN      NaN
# 27047                        NaN      NaN
# 27048                        NaN      NaN
# 27049                        NaN      NaN
# 27050                        NaN      NaN
# 27051                        NaN      NaN
# 27052                        NaN      NaN
# 27053                        NaN      NaN
#
# [27054 rows x 16 columns]

# %%
# Finding the shape of the data frame
individuals_carbon_footprint_df.shape
# Out:
# (27054, 16)

# %% [markdown]
# ## Section 3 - Augmenting Data (Unpivot Dataframe)

# %% [markdown]
# This section is responsible to convert the data from 2-Dimensional Table Form which compares data of every individual v/s the type of resource used to a 1-Dimensional Table that lists out the data per individual. This process is like the reverse of pivoting a table.

# %%
# Converting the Dataset from a Big 2 Dimensional Individual v/s Resource Used table to Per Individual focused tabele 
individuals_carbon_footprint_table = pd.melt(individuals_carbon_footprint_df, id_vars=['Indnum', 'Group',
                                                                                       'Activity', 'Units', 'Consumption',
                                                                                       'Quality_of_Life_Importance__1_10'],
                                             value_vars=individuals_carbon_footprint_df.columns.values[6:],
                                             var_name='Name of Resource Used', value_name='Amount of Resource Used per Unit')

# %%
individuals_carbon_footprint_table
# Out:
#         Indnum  Group                                        Activity  Units  \
# 0            1      1                        Household heating => 70F  hours
# 1            1      1                         Household heating < 70F  hours
# 2            1      1                                Use of heat pump  hours
# 3            1      1                          Use of air conditioner  hours
# 4            1      2                                  shower - short  count
# 5            1      2                         shower - long (> 3 min)  count
# 6            1      2                                            bath  count
# 7            1      2                                         wash-up  count
# 8            1      3                               use of dishwasher  count
# 9            1      3                           use of clothes washer  count
# 10           1      3                            use of clothes dryer  count
# 11           1      3                            use of cooking range  count
# 12           1      3                                    use of  oven  count
# 13           1      3      use of self-clean feature of electric oven  count
# 14           1      3             Small kitchen appliance in the home  count
# 15           1      4                                 TV/computer use  count
# 16           1      5                        air travel - large plane  miles
# 17           1      5           air travel - small  plane (<50 seats)  miles
# 18           1      5                            car trips- self only  miles
# 19           1      5                     car trips - driver and self  miles
# 20           1      5  car trips - 2+ people with multiple end points  miles
# 21           1      5        trips using public ground transportation   bags
# 22           1      6                        bags of garbage disposed   bags
# 23           1      6       bags of recycling deposited (negative CF)   bags
# 24           1      6         bags of compost deposited (negative CF)   bags
# 25           1      6            hazardous or electric items disposed   bags
# 26           1      6                            large items disposed  items
# 27           2      1                        Household heating => 70F  count
# 28           2      1                         Household heating < 70F  count
# 29           2      1                                Use of heat pump  count
# ...        ...    ...                                             ...    ...
# 270510    1001      6         bags of compost deposited (negative CF)   bags
# 270511    1001      6            hazardous or electric items disposed   bags
# 270512    1001      6                            large items disposed  items
# 270513    1002      1                        Household heating => 70F  count
# 270514    1002      1                         Household heating < 70F  count
# 270515    1002      1                                Use of heat pump  count
# 270516    1002      1                          Use of air conditioner  count
# 270517    1002      2                                  shower - short  count
# 270518    1002      2                         shower - long (> 3 min)  count
# 270519    1002      2                                            bath  count
# 270520    1002      2                                         wash-up  count
# 270521    1002      3                               use of dishwasher  count
# 270522    1002      3                           use of clothes washer  count
# 270523    1002      3                            use of clothes dryer  count
# 270524    1002      3                            use of cooking range  count
# 270525    1002      3                                    use of  oven  count
# 270526    1002      3      use of self-clean feature of electric oven  count
# 270527    1002      3             Small kitchen appliance in the home  count
# 270528    1002      4                                 TV/computer use  count
# 270529    1002      5                        air travel - large plane  miles
# 270530    1002      5           air travel - small  plane (<50 seats)  miles
# 270531    1002      5                            car trips- self only  miles
# 270532    1002      5                     car trips - driver and self  miles
# 270533    1002      5  car trips - 2+ people with multiple end points  miles
# 270534    1002      5        trips using public ground transportation   bags
# 270535    1002      6                        bags of garbage disposed   bags
# 270536    1002      6       bags of recycling deposited (negative CF)   bags
# 270537    1002      6         bags of compost deposited (negative CF)   bags
# 270538    1002      6            hazardous or electric items disposed   bags
# 270539    1002      6                            large items disposed  items
#
#         Consumption  Quality_of_Life_Importance__1_10  \
# 0               2.0                              88.0
# 1              10.0                              85.0
# 2               NaN                              50.0
# 3              20.0                              45.0
# 4               5.0                              98.0
# 5              30.0                              74.0
# 6               NaN                              14.0
# 7              44.0                              27.0
# 8               NaN                              20.0
# 9               2.0                              28.0
# 10              3.0                              11.0
# 11              NaN                               NaN
# 12              9.0                              35.0
# 13              3.0                              15.0
# 14              NaN                               NaN
# 15             64.0                              23.0
# 16           2747.0                              42.0
# 17              NaN                               NaN
# 18            443.0                              44.0
# 19             38.0                              27.0
# 20             10.0                               NaN
# 21             15.0                              49.0
# 22             26.0                              41.0
# 23              NaN                               NaN
# 24              3.0                               6.0
# 25              NaN                               NaN
# 26              2.0                              15.0
# 27              7.0                              77.0
# 28              2.0                              61.0
# 29              NaN                              55.0
# ...             ...                               ...
# 270510          NaN                               NaN
# 270511          NaN                               NaN
# 270512          NaN                              19.0
# 270513          1.0                              82.0
# 270514          2.0                              83.0
# 270515          NaN                              50.0
# 270516         16.0                              56.0
# 270517          8.0                              84.0
# 270518         23.0                              89.0
# 270519          NaN                              11.0
# 270520         42.0                              34.0
# 270521          NaN                              20.0
# 270522          3.0                              32.0
# 270523          1.0                              14.0
# 270524          NaN                               NaN
# 270525         12.0                              33.0
# 270526          3.0                              20.0
# 270527          NaN                               NaN
# 270528         64.0                              29.0
# 270529       3166.0                              42.0
# 270530          NaN                               NaN
# 270531        323.0                              54.0
# 270532         11.0                              22.0
# 270533          NaN                               NaN
# 270534         16.0                              57.0
# 270535         26.0                              51.0
# 270536          NaN                               NaN
# 270537          7.0                              15.0
# 270538          NaN                               NaN
# 270539          1.0                              14.0
#
#               Name of Resource Used  Amount of Resource Used per Unit
# 0       solar_powered__water_heater                               NaN
# 1       solar_powered__water_heater                               1.0
# 2       solar_powered__water_heater                               NaN
# 3       solar_powered__water_heater                               NaN
# 4       solar_powered__water_heater                               NaN
# 5       solar_powered__water_heater                               NaN
# 6       solar_powered__water_heater                               NaN
# 7       solar_powered__water_heater                               NaN
# 8       solar_powered__water_heater                               NaN
# 9       solar_powered__water_heater                               NaN
# 10      solar_powered__water_heater                               NaN
# 11      solar_powered__water_heater                               NaN
# 12      solar_powered__water_heater                               NaN
# 13      solar_powered__water_heater                               NaN
# 14      solar_powered__water_heater                               NaN
# 15      solar_powered__water_heater                               NaN
# 16      solar_powered__water_heater                               NaN
# 17      solar_powered__water_heater                               NaN
# 18      solar_powered__water_heater                               NaN
# 19      solar_powered__water_heater                               NaN
# 20      solar_powered__water_heater                               NaN
# 21      solar_powered__water_heater                               NaN
# 22      solar_powered__water_heater                               NaN
# 23      solar_powered__water_heater                               NaN
# 24      solar_powered__water_heater                               NaN
# 25      solar_powered__water_heater                               NaN
# 26      solar_powered__water_heater                               NaN
# 27      solar_powered__water_heater                               NaN
# 28      solar_powered__water_heater                               NaN
# 29      solar_powered__water_heater                               NaN
# ...                             ...                               ...
# 270510                      jetfuel                               NaN
# 270511                      jetfuel                               NaN
# 270512                      jetfuel                               NaN
# 270513                      jetfuel                               NaN
# 270514                      jetfuel                               NaN
# 270515                      jetfuel                               NaN
# 270516                      jetfuel                               NaN
# 270517                      jetfuel                               NaN
# 270518                      jetfuel                               NaN
# 270519                      jetfuel                               NaN
# 270520                      jetfuel                               NaN
# 270521                      jetfuel                               NaN
# 270522                      jetfuel                               NaN
# 270523                      jetfuel                               NaN
# 270524                      jetfuel                               NaN
# 270525                      jetfuel                               NaN
# 270526                      jetfuel                               NaN
# 270527                      jetfuel                               NaN
# 270528                      jetfuel                               NaN
# 270529                      jetfuel                               NaN
# 270530                      jetfuel                               NaN
# 270531                      jetfuel                               NaN
# 270532                      jetfuel                               NaN
# 270533                      jetfuel                               NaN
# 270534                      jetfuel                               NaN
# 270535                      jetfuel                               NaN
# 270536                      jetfuel                               NaN
# 270537                      jetfuel                               NaN
# 270538                      jetfuel                               NaN
# 270539                      jetfuel                               NaN
#
# [270540 rows x 8 columns]

# %%
# Finding the shape of the new table to make sure that no data is lost
# The new number of records should be equal to the number of individuals * the number of different resources available.
# Here it is equal to - 27054 * 10 - 270540
individuals_carbon_footprint_table.shape
# Out:
# (270540, 8)

# %% [markdown]
# ## Section 4 - Handling NaN Values

# %% [markdown]
# This section is responsible to actually handle/filter the various NaN values present in the Amount Column of the table when the dataframe has been melted (unpivoted)

# %%
#Cleaning the table, by dropping the records where we have NaN values in the column of amount of resource used per unit
individuals_carbon_footprint_table_drop_na = individuals_carbon_footprint_table.dropna(axis = 0)

# %%
# Make sure the data is as expected
individuals_carbon_footprint_table_drop_na.head()
# Out:
#      Indnum  Group                 Activity  Units  Consumption  \
# 1         1      1  Household heating < 70F  hours         10.0
# 34        2      2                  wash-up  count         44.0
# 59        3      2  shower - long (> 3 min)  count         40.0
# 61        3      2                  wash-up  count         45.0
# 117       5      3    use of clothes washer  count          7.0
#
#      Quality_of_Life_Importance__1_10        Name of Resource Used  \
# 1                                85.0  solar_powered__water_heater
# 34                               34.0  solar_powered__water_heater
# 59                               85.0  solar_powered__water_heater
# 61                               27.0  solar_powered__water_heater
# 117                              41.0  solar_powered__water_heater
#
#      Amount of Resource Used per Unit
# 1                                 1.0
# 34                                1.0
# 59                                1.0
# 61                                1.0
# 117                               1.0

# %%
# Finding the new number of records left after removing NaN Values
individuals_carbon_footprint_table_drop_na.shape
# Out:
# (8997, 8)

# %%
# Cleaning the table, by replacing the records where we have NaN values in the column of amount of resource used per unit with 0.0
individuals_carbon_footprint_table_replace_na_zero = individuals_carbon_footprint_table
individuals_carbon_footprint_table_replace_na_zero['Amount of Resource Used per Unit'] = np.nan_to_num(
    individuals_carbon_footprint_table_replace_na_zero['Amount of Resource Used per Unit'])

# %%
# Make sure the data is as expected
individuals_carbon_footprint_table_replace_na_zero.head()
# Out:
#    Indnum  Group                  Activity  Units  Consumption  \
# 0       1      1  Household heating => 70F  hours          2.0
# 1       1      1   Household heating < 70F  hours         10.0
# 2       1      1          Use of heat pump  hours          NaN
# 3       1      1    Use of air conditioner  hours         20.0
# 4       1      2            shower - short  count          5.0
#
#    Quality_of_Life_Importance__1_10        Name of Resource Used  \
# 0                              88.0  solar_powered__water_heater
# 1                              85.0  solar_powered__water_heater
# 2                              50.0  solar_powered__water_heater
# 3                              45.0  solar_powered__water_heater
# 4                              98.0  solar_powered__water_heater
#
#    Amount of Resource Used per Unit
# 0                               0.0
# 1                               1.0
# 2                               0.0
# 3                               0.0
# 4                               0.0

# %%
# Making sure that no record is dropped
individuals_carbon_footprint_table_replace_na_zero.shape
# Out:
# (270540, 8)

# %% [markdown]
# ## Section 5 - Saving the Tables

# %% [markdown]
# This section is used to save the tables generated into csv files as part of saving data as we clean and filter it.

# %%
# Saving these data_frames into csv_files
individuals_carbon_footprint_table_drop_na.to_csv(r'Individuals_Carbon_Footprint_NA_Dropped.csv', index=False)
individuals_carbon_footprint_table_replace_na_zero.to_csv(r'Individuals_Carbon_Footprint_NA_Zeroed.csv', index=False)
